# %% [markdown]
# # Chap4. 그래프 그리기

# %% [markdown]
# # 04-1 데이터 시각화 필요성

# %% [markdown]
# ## 📌앤스콤(Anscombe's quartet)

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### 앤스콤 데이터 불러오기

# %%
anscombe = sns.load_dataset('anscombe')
anscombe
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %% [markdown]
# ### matplotlib 라이브러리로 그래프 그리기

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
dataset1 = anscombe[anscombe['dataset'] == 'I']

# %%
plt.plot(dataset1['x'], dataset1['y'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(dataset1['x'], dataset1['y'], 'o')

# %%
dataset1 = anscombe[anscombe['dataset'] == 'I']
dataset2 = anscombe[anscombe['dataset'] == 'II']
dataset3 = anscombe[anscombe['dataset'] == 'III']
dataset4 = anscombe[anscombe['dataset'] == 'IV']

# %%
#1. 그래프 기본 틀 생성

fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#2. 그래프 격자 그리기 
#add_subplot(행, 열)

axes1 = fig.add_subplot(2, 2, 1)
axes2 = fig.add_subplot(2, 2, 2)
axes3 = fig.add_subplot(2, 2, 3)
axes4 = fig.add_subplot(2, 2, 4)

# %%
#3. 데이터 전달하여 그래프 그리기

axes1.plot(dataset1['x'], dataset1['y'], 'o')
axes2.plot(dataset2['x'], dataset2['y'], 'o')
axes3.plot(dataset3['x'], dataset3['y'], 'o')
axes4.plot(dataset4['x'], dataset4['y'], 'o')

# %%
#4. 각 그래프 격자에 제목 추가

axes1.set_title('dataset1')
axes2.set_title('dataset2')
axes3.set_title('dataset3')
axes4.set_title('dataset4')
# Out:
# Text(0.5, 1.0, 'dataset4')

# %%
#5. 전체 그래프 제목 추가

fig.suptitle('Anscombe Data')
# Out:
# Text(0.5, 0.98, 'Anscombe Data')

# %%
#6. 그래프 레이아웃 조절

fig.tight_layout()

# %% [markdown]
# # 04-2 matplotlib 라이브러리로 그래프 그리기

# %%
#식당에서 팁을 지불한 손님 데이터를 모아놓은 tips 데이터셋 로드

tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### 히스토그램

# %%
fig = plt.figure()
axes1 = fig.add_subplot(1, 1, 1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#tips 데이터의 total_bill 컬럼으로 히스토그램 그래프 생성

axes1.hist(tips['total_bill'], bins=10)
axes1.set_title('Histogram of Total Bill')
axes1.set_xlabel('Frequency')
axes1.set_ylabel('Total Bill')
# Out:
# Text(47.9375, 0.5, 'Total Bill')

# %% [markdown]
# ### 산점도

# %%
scatter_plot = plt.figure()

axes1 = scatter_plot.add_subplot(1, 1, 1)
axes1.scatter(tips['total_bill'], tips['tip'])
axes1.set_title('Scatterplot of Total Bill vs Tip')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Tip')

# %% [markdown]
# ### 박스그래프

# %%
box_plot = plt.figure()

axes1 = box_plot.add_subplot(1, 1, 1)
axes1.boxplot(
    [
        tips[tips['sex'] == 'Female']['tip']
        ,tips[tips['sex'] == 'Male']['tip']
    ],
    labels=['Female', 'Male']
)
axes1.set_title('Boxplot of Tiips by Sex')
axes1.set_xlabel('Sex')
axes1.set_ylabel('Tip')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Tip')

# %% [markdown]
# ### 다변량 데이터로 다변량 그래프 - 산점도
# - 색상, 크기 등을 다르게 하여 구분할 수 있음

# %%
#0과 1의 숫자로만 지정할 수 있으므로 Sex 컬럼의 문자열을 숫자로 바꿔주는 작업 진행
#메서드 반환값을 데이터프레임에 추가

def recode_sex(sex):
    if sex == 'Female':
        return 0
    else:
        return 1

# %%
tips['sex_color'] = tips['sex'].apply(recode_sex)

# %%
scatter_plot = plt.figure()

axes1 = scatter_plot.add_subplot(1, 1, 1)
axes1.scatter(
    x=tips['total_bill']
    ,y=tips['tip']
    ,s=tips['size'] * 10    #점의 크기
    ,c=tips['sex_color']   #점의 색상
    ,alpha=0.5               #점의 투명도
)
axes1.set_title('Total Bill vs Tip Colored by Sex and Sized by Size')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Tip')

# %% [markdown]
# # 04-3 seaborn 라이브러리로 그래프 그리기

# %%
ax = plt.subplots() #기본틀 생성
ax = sns.distplot(tips['total_bill']) #컬럼 전달
ax.set_title('Total Bill Histogram with Density Plot')
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Users\serye\AppData\Local\Temp\ipykernel_26040\3748855893.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill']) #컬럼 전달
# Text(0.5, 1.0, 'Total Bill Histogram with Density Plot')

# %%
#밀집도 그래프 삭제
#kde=False

ax = plt.subplots() #기본틀 생성
ax = sns.distplot(tips['total_bill'], kde=False) #컬럼 전달
ax.set_title('Total Bill Histogram')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Frequency')
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Users\serye\AppData\Local\Temp\ipykernel_26040\1548917505.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill'], kde=False) #컬럼 전달
# Text(0, 0.5, 'Frequency')

# %%
#밀집도 그래프만 표현
#hist=False

ax = plt.subplots() #기본틀 생성
ax = sns.distplot(tips['total_bill'], hist=False) #컬럼 전달
ax.set_title('Total Bill Histogram')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Unit Probability')
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Users\serye\AppData\Local\Temp\ipykernel_26040\1631256720.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill'], hist=False) #컬럼 전달
# Text(0, 0.5, 'Unit Probability')

# %%
#히스토그램 & 밀집도 & 양탄자 그래프
#rug=True

ax = plt.subplots() #기본틀 생성
ax = sns.distplot(tips['total_bill'], rug=True) #컬럼 전달
ax.set_title('Total Bill Histogram with Density and Rug Plot')
ax.set_xlabel('Total BIll')
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Users\serye\AppData\Local\Temp\ipykernel_26040\3117000799.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill'], rug=True) #컬럼 전달
# Text(0.5, 0, 'Total BIll')

# %% [markdown]
# ### count 그래프

# %%
tips = sns.load_dataset('tips')

count_g = plt.subplots()
count_g = sns.countplot(x='day', data=tips)
count_g.set_title('Count of days')
count_g.set_xlabel('Day of the Week')
count_g.set_ylabel('Frequency')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ### 다양한 종류의 이변량 그래프

# %%
#산점도 그래프 & 회귀선

ax = plt.subplots()
ax = sns.regplot(x='total_bill', y='tip', data=tips)
ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Tip')

# %%
#산점도 그래프 & 회귀선 제거
#fit_reg=False

ax = plt.subplots()
ax = sns.regplot(x='total_bill', y='tip', data=tips, fit_reg=False)
ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Tip')

# %%
#산점도 그래프 & 히스토그램
#jointplot

joint = sns.jointplot(x='total_bill', y='tip', data=tips)
joint.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
joint.fig.suptitle('Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# <img src="data:image/png;base64,..." width="600">
# Text(0.5, 1.03, 'Joint Plot of Total Bill and Tip')

# %%
# 산점도 그래프의 단점 보완 -> 육각 그래프

hexbin = sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex')
hexbin.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
hexbin.fig.suptitle('Hexbin Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# <img src="data:image/png;base64,..." width="600">
# Text(0.5, 1.03, 'Hexbin Joint Plot of Total Bill and Tip')

# %%
#이차원 밀집도 그리기

ax = plt.subplots()
ax = sns.kdeplot(
    x=tips['total_bill']
    ,y=tips['tip']
    ,shade=True #그래프 음영 효과
)
ax.set_title('Kernel Density Plot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Users\serye\AppData\Local\Temp\ipykernel_26040\1835468762.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(
# Text(0, 0.5, 'Tip')

# %%
#바 그래프 그리기

ax = plt.subplots()
ax = sns.barplot(x='time', y='total_bill', data=tips)
ax.set_title('Bar plot of average total bill for time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Average total bill')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Average total bill')

# %%
#박스 그래프 그리기

ax = plt.subplots()
ax = sns.boxplot(x='time', y='total_bill', data=tips)
ax.set_title('Box plot of average total bill for time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Total bill')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Total bill')

# %% [markdown]
# ▶ 박스 그래프의 경우 데이터 분산이 모호하게 표현됨.

# %%
#박스 그래프에 커널 밀도를 추정한 바이올린 그래프

ax = plt.subplots()
ax = sns.violinplot(x='time', y='total_bill', data=tips)
ax.set_title('Violin plot of average total bill for time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Total bill')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Total bill')

# %% [markdown]
# ### 관계 그래프

# %%
#관계 그래프  (다양한 종류의 그래프를 종합한 그래프)

fig = sns.pairplot(tips)
# Out:
# <img src="data:image/png;base64,..." width="750.2222222222222">

# %%
#관계 그래프는 중복된 정보가 포함됨
#-> 중복된 그래프가 그려지는 위치를 직접 원하는 그래프로 교체

pair_grid = sns.PairGrid(tips)
pair_grid = pair_grid.map_upper(sns.regplot)                 #대각선을 기준으로 위 (산점도)
pair_grid = pair_grid.map_lower(sns.kdeplot)                 #대각선을 기준으로 아래 (이차원 밀집도)
pair_grid = pair_grid.map_diag(sns.distplot, rug=True) #대각선 중심 (히스토그램 & 밀집도)

plt.show()
# Out:
# C:\Users\serye\anaconda3\lib\site-packages\seaborn\axisgrid.py:1274: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = plt.figure(figsize=figsize)
# <img src="data:image/png;base64,..." width="750.2222222222222">
# C:\Users\serye\anaconda3\lib\site-packages\seaborn\axisgrid.py:1544: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# ### 다변량 그래프

# %%
#바이올린 그래프 색상 추가
#hue='색상에 사용할 컬럼'

ax = plt.subplots()
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#산점도 관계 그래프 색상 추가

scatter = sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', fit_reg=False)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
fig = sns.pairplot(tips, hue='sex')
# Out:
# <img src="data:image/png;base64,..." width="849.7777777777778">

# %%
#산점도 그래프 크기 조절하기
#scatter_kws <- 딕셔너리 파라미터값

#tips['size']
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex', scatter_kws={'s' : 10})

# %%
#산점도 그래프 모양 조절하기
#scatter_kws <- 딕셔너리 파라미터값

#tips['size']
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex', scatter_kws={'s' : 10}, markers=['o', 'x'])

# %%
#4개의 데이터 그룹에 대한 그래프 한 번에 그리기 -> lmplot

anscombe_plot = sns.lmplot(x='x', y='y', data=anscombe, fit_reg=False)

# %%
#그룹별로 그래프 나누어 그리기

anscombe_plot = sns.lmplot(x='x', y='y', data=anscombe, fit_reg=False, col='dataset', col_wrap=4)

# %%
#FacetGrid 클래스 사용하여 그룹별 그래프 그리기
#map(그래프종류, x축 컬럼명)

facet = sns.FacetGrid(tips, col='time')
facet.map(sns.distplot, 'total_bill', rug=True)
# Out:
# C:\Users\serye\anaconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\serye\anaconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
#tips 데이터 집합의 day 열로 그룹을 구분한 그래프

facet = sns.FacetGrid(tips, col='day', hue='sex')
facet = facet.map(plt.scatter, 'total_bill', 'tip')
facet = facet.add_legend()
# Out:
# <img src="data:image/png;base64,..." width="1300.4444444444443">

# %%
#더 많은 변수 사용하여 그래프 그리기
#smoker, time 컬럼은 각각 2개의 값을 가지므로 2x2 격자 생성됨

facet = sns.FacetGrid(tips, col='time', row='smoker', hue='sex')
facet.map(plt.scatter, 'total_bill', 'tip')
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# # 04-4 데이터프레임과 시리즈로 그래프 그리기

# %% [markdown]
# ### 시리즈의 hist() 사용하여 히스토그램

# %%
#1개의 시리즈

ax = plt.subplots()
ax = tips['total_bill'].plot.hist()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#2개의 시리즈

fig, ax = plt.subplots()
ax = tips[['total_bill', 'tip']].plot.hist(alpha=0.5, bins=20, ax=ax) #alpha:투명도, bins:x축 간격
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### 밀집도

# %%
ax = plt.subplots()
ax = tips['tip'].plot.kde()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### 산점도

# %%
fig, ax = plt.subplots()
ax = tips.plot.scatter(x='total_bill', y='tip', ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### 육각 그래프

# %%
fig, ax = plt.subplots()
ax = tips.plot.hexbin(x='total_bill', y='tip', ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()
ax = tips.plot.hexbin(x='total_bill', y='tip', gridsize=10, ax=ax) #육각 크기 변경 가능
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### 박스 그래프

# %%
fig, ax = plt.subplots()
ax = tips.plot.box(ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # 04-5 seaborn 라이브러리로 그래프 스타일 설정하기
# - set_style()

# %%
fig, ax = plt.subplots()
ax = sns.violinplot(x='time', y='tip', hue='sex', data=tips, split=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sns.set_style('whitegrid')

fig, ax = plt.subplots()
ax = sns.violinplot(x='time', y='tip', hue='sex', data=tips, split=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#모든 스타일 리스트에 담아두고 하나씩 적용하기

fig = plt.figure()

seaborn_style = ['darkgrid', 'whitegrid', 'dark', 'white', 'ticks']
for idx, style in enumerate(seaborn_style):
    plot_position = idx + 1
    with sns.axes_style(style):
        ax = fig.add_subplot(2, 3, plot_position)
        violin = sns.violinplot(x='time', y='tip', data=tips, ax=ax)
        violin.set_title(style)
        
fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">
